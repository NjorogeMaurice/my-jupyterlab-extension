# %%
import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 2.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 3.4 MB/s eta 0:00:004.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_csv("https://open.africa/dataset/d23f4ee9-32a9-4df2-afeb-c4700d061275/resource/46c842f7-c507-4c4f-b5ca-cdb07355f438/download/cfafrica-data-team-covid-19-data-openafrica-uploads-south-africa-type-of-handwashing-facility.csv")

# %%
data.head()
# Out:
#         Geography  Soap and water  \
# 0          Urban             57.0
# 1      Non-urban             34.5
# 2   Western Cape             86.1
# 3   Eastern Cape             45.4
# 4  Northern Cape             54.2
#
#    Water and cleansing agent other than soap only  Water only  \
# 0                                             1.1        31.8
# 1                                             0.7        37.7
# 2                                             1.0        12.0
# 3                                             0.7        36.3
# 4                                             0.6        33.5
#
#    Soap but no water  Cleansing agent other than soap only  \
# 0                1.3                                   0.0
# 1                1.3                                   0.0
# 2                0.0                                   0.0
# 3                0.6                                   0.0
# 4                1.2                                   0.0
#
# ...
