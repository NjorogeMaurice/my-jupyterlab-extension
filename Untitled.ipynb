# %%
import pandas as pd

# %%
# %pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 KB 2.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 3.4 MB/s eta 0:00:004.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_csv('https://ckandev.africadatahub.org/dataset/e815d9f5-46aa-497c-b7d0-ec674f6b4ebf/resource/f0ea7193-1414-4aaf-a474-76938623318a/download/power_bi.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data=pd.read_csv('https://ckandev.africadatahub.org/dataset/e815d9f5-46aa-497c-b7d0-ec674f6b4ebf/resource/f0ea7193-1414-4aaf-a474-76938623318a/download/power_bi.csv')
#
# ...

# %%
data.head()
# Out:
#         Geography  Getting\rpermission to go\rfor treatment  \
# 0          Urban                                        9.9
# 1      Non-urban                                       24.1
# 2   Western Cape                                        7.2
# 3   Eastern Cape                                       14.2
# 4  Northern Cape                                       15.8
#
#    Getting money\rfor treatment  Distance to\rhealth facility  \
# 0                          22.0                          15.6
# 1                          39.8                          41.1
# 2                          16.0                          11.3
# 3                          37.0                          34.2
# 4                          28.0                          23.7
#
#    Not wanting to\rgo alone  At least one\rproblem\raccessing\rhealth care  \
# 0                       9.3                                           30.4
# 1                      24.4                                           53.4
# ...
